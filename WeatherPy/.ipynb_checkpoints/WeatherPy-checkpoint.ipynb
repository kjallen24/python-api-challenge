# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from keys import openweatherkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy 

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print((cities[0]))
# Out:
# nizhneyansk

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#{"coord":{"lon":-133.0374,"lat":69.4541},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"base":"stations","main":{"temp":21.2,"feels_like":10.13,"temp_min":21.2,"temp_max":21.2,"pressure":1007,"humidity":79},"visibility":10000,"wind":{"speed":10.36,"deg":70},"clouds":{"all":20},"dt":1619823061,"sys":{"type":1,"id":942,"country":"CA","sunrise":1619782384,"sunset":1619849121},"timezone":-21600,"id":6170031,"name":"Tuktoyaktuk","cod":200}

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + openweatherkey
citydata = []
citycount = len(cities)
for index, city in enumerate(cities):
    cityurl = url + "&q=" + city
    try: 
        print("Processing Record {} of {}".format(index + 1, citycount))
        response = requests.get(cityurl).json()
        citydata.append(response)
    except: 
        print("{} not found".format(city))
print("Done")
# Out:
# Processing Record 1 of 627
# Processing Record 2 of 627
# Processing Record 3 of 627
# Processing Record 4 of 627
# Processing Record 5 of 627
# Processing Record 6 of 627
# Processing Record 7 of 627
# Processing Record 8 of 627
# Processing Record 9 of 627
# Processing Record 10 of 627
# Processing Record 11 of 627
# Processing Record 12 of 627
# Processing Record 13 of 627
# Processing Record 14 of 627
# Processing Record 15 of 627
# Processing Record 16 of 627
# Processing Record 17 of 627
# Processing Record 18 of 627
# Processing Record 19 of 627
# Processing Record 20 of 627
# Processing Record 21 of 627
# Processing Record 22 of 627
# Processing Record 23 of 627
# Processing Record 24 of 627
# Processing Record 25 of 627
# Processing Record 26 of 627
# Processing Record 27 of 627
# Processing Record 28 of 627
# Processing Record 29 of 627
# Processing Record 30 of 627
# Processing Record 31 of 627
# Processing Record 32 of 627
# Processing Record 33 of 627
# Processing Record 34 of 627
# Processing Record 35 of 627
# Processing Record 36 of 627
# Processing Record 37 of 627
# Processing Record 38 of 627
# Processing Record 39 of 627
# Processing Record 40 of 627
# Processing Record 41 of 627
# Processing Record 42 of 627
# Processing Record 43 of 627
# Processing Record 44 of 627
# Processing Record 45 of 627
# Processing Record 46 of 627
# Processing Record 47 of 627
# Processing Record 48 of 627
# Processing Record 49 of 627
# Processing Record 50 of 627
# Processing Record 51 of 627
# Processing Record 52 of 627
# Processing Record 53 of 627
# Processing Record 54 of 627
# Processing Record 55 of 627
# Processing Record 56 of 627
# Processing Record 57 of 627
# Processing Record 58 of 627
# Processing Record 59 of 627
# Processing Record 60 of 627
# Processing Record 61 of 627
# Processing Record 62 of 627
# Processing Record 63 of 627
# Processing Record 64 of 627
# Processing Record 65 of 627
# Processing Record 66 of 627
# Processing Record 67 of 627
# Processing Record 68 of 627
# Processing Record 69 of 627
# Processing Record 70 of 627
# Processing Record 71 of 627
# Processing Record 72 of 627
# Processing Record 73 of 627
# Processing Record 74 of 627
# Processing Record 75 of 627
# Processing Record 76 of 627
# Processing Record 77 of 627
# Processing Record 78 of 627
# Processing Record 79 of 627
# Processing Record 80 of 627
# Processing Record 81 of 627
# Processing Record 82 of 627
# Processing Record 83 of 627
# Processing Record 84 of 627
# Processing Record 85 of 627
# Processing Record 86 of 627
# Processing Record 87 of 627
# Processing Record 554 of 627
# Processing Record 555 of 627
# Processing Record 556 of 627
# Processing Record 557 of 627
# Processing Record 558 of 627
# Processing Record 559 of 627
# Processing Record 560 of 627
# Processing Record 561 of 627
# Processing Record 562 of 627
# Processing Record 563 of 627
# Processing Record 564 of 627
# Processing Record 565 of 627
# Processing Record 566 of 627
# Processing Record 567 of 627
# Processing Record 568 of 627
# Processing Record 569 of 627
# Processing Record 570 of 627
# Processing Record 571 of 627
# Processing Record 572 of 627
# Processing Record 573 of 627
# Processing Record 574 of 627
# Processing Record 575 of 627
# Processing Record 576 of 627
# Processing Record 577 of 627
# Processing Record 578 of 627
# Processing Record 579 of 627
# Processing Record 580 of 627
# Processing Record 581 of 627
# Processing Record 582 of 627
# Processing Record 583 of 627
# Processing Record 584 of 627
# Processing Record 585 of 627
# Processing Record 586 of 627
# Processing Record 587 of 627
# Processing Record 588 of 627
# Processing Record 589 of 627
# Processing Record 590 of 627
# Processing Record 591 of 627
# Processing Record 592 of 627
# Processing Record 593 of 627
# Processing Record 594 of 627
# Processing Record 595 of 627
# Processing Record 596 of 627
# Processing Record 597 of 627
# Processing Record 598 of 627
# Processing Record 599 of 627
# Processing Record 600 of 627
# Processing Record 601 of 627
# Processing Record 602 of 627
# Processing Record 603 of 627
# Processing Record 604 of 627
# Processing Record 605 of 627
# Processing Record 606 of 627
# Processing Record 607 of 627
# Processing Record 608 of 627
# Processing Record 609 of 627
# Processing Record 610 of 627
# Processing Record 611 of 627
# Processing Record 612 of 627
# Processing Record 613 of 627
# Processing Record 614 of 627
# Processing Record 615 of 627
# Processing Record 616 of 627
# Processing Record 617 of 627
# Processing Record 618 of 627
# Processing Record 619 of 627
# Processing Record 620 of 627
# Processing Record 621 of 627
# Processing Record 622 of 627
# Processing Record 623 of 627
# Processing Record 624 of 627
# Processing Record 625 of 627
# Processing Record 626 of 627
# Processing Record 627 of 627
# Done

# %%
#sample = {'coord': {'lon': 92.0667, 'lat': 49.9811}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 49.64, 'feels_like': 47.59, 'temp_min': 49.64, 'temp_max': 49.64, 'pressure': 1002, 'humidity': 62, 'sea_level': 1002, 'grnd_level': 896}, 'visibility': 10000, 'wind': {'speed': 5.37, 'deg': 319, 'gust': 5.46}, 'clouds': {'all': 56}, 'dt': 1619823805, 'sys': {'country': 'MN', 'sunrise': 1619821698, 'sunset': 1619874552}, 'timezone': 25200, 'id': 1515029, 'name': 'Ulaangom', 'cod': 200}

all_citydata = []
for weathercity in citydata:
    try:
        statuscod = int(weathercity["cod"])
        if statuscod == 200:
            cityname = weathercity["name"]
            print("Processing Record {}".format(cityname))
            lat = weathercity["coord"]["lat"]
            long = weathercity["coord"]["lon"]
            maxtemp = weathercity["main"]["temp_max"]
            humidity = weathercity["main"]["humidity"]
            Cloudiness = weathercity["clouds"]["all"]
            WindSpeed = weathercity["wind"]["speed"]
            Country = weathercity["sys"]["country"]
            citydate = weathercity["dt"]
            dict_items = {"City": cityname, "Lat": lat, "Lng": long, "Max Temp": maxtemp, "Humidity": humidity, "Cloudiness": Cloudiness,
                         "Wind Speed": WindSpeed, "Country": Country, "Date": citydate}
            all_citydata.append(dict_items)
    except: 
        print("{} not found".format(weathercity))
    
#print(sample.keys())
# Out:
# Processing Record Hermanus
# Processing Record Hamilton
# Processing Record Vaini
# Processing Record Yukhnov
# Processing Record Ziniaré
# Processing Record Kaitangata
# Processing Record Mar del Plata
# Processing Record Olafsvik
# Processing Record Lebu
# Processing Record Parabel'
# Processing Record Nacala
# Processing Record Puerto Ayora
# Processing Record Yellowknife
# Processing Record Loukhi
# Processing Record Punta Arenas
# Processing Record Ballitoville
# Processing Record Hobart
# Processing Record Rikitea
# Processing Record Kūhdasht
# Processing Record Hilo
# Processing Record Bredasdorp
# Processing Record Caravelas
# Processing Record Hasaki
# Processing Record Portalegre
# Processing Record Souillac
# Processing Record Dingle
# Processing Record Tuktoyaktuk
# Processing Record Albany
# Processing Record Port Alfred
# Processing Record Yerbogachën
# Processing Record Nanortalik
# Processing Record Qaanaaq
# Processing Record Solnechnyy
# Processing Record Faanui
# Processing Record Paamiut
# Processing Record Morón
# Processing Record Kysyl-Syr
# Processing Record Svetlaya
# Processing Record Gualeguay
# Processing Record Saravan
# Processing Record Porto-Novo
# Processing Record Longyearbyen
# Processing Record Cocobeach
# Processing Record Bluff
# Processing Record Roswell
# Processing Record Ushuaia
# Processing Record Lypnyazhka
# Processing Record Sinnamary
# Processing Record Ilo
# Processing Record Ballina
# Processing Record Husavik
# Processing Record Arman'
# Processing Record Sokoto
# Processing Record Otuzco
# Processing Record New Norfolk
# Processing Record Inhambane
# Processing Record Rocha
# Processing Record Okhotsk
# Processing Record Vardø
# Processing Record Iqaluit
# Processing Record Atuona
# Processing Record Cape Town
# Processing Record San Quintín
# Processing Record Coquimbo
# Processing Record Berdigestyakh
# Processing Record Berlevåg
# Processing Record Esperance
# Processing Record Jamestown
# Processing Record Keti Bandar
# Processing Record Uruçuí
# Processing Record Saint George
# Processing Record Mataura
# Processing Record Acapulco de Juárez
# Processing Record Erdenet
# Processing Record Great Yarmouth
# Processing Record East London
# Processing Record Cabedelo
# Processing Record Thompson
# Processing Record Kapaa
# Processing Record Nakapiripirit
# Processing Record Klaksvík
# Processing Record Saldanha
# Processing Record Makkah al Mukarramah
# Processing Record Papara
# Processing Record Barrow
# Processing Record Santa Cruz de la Sierra
# Processing Record Chaiya
# Processing Record Bandar-e Lengeh
# Processing Record Butaritari
# Processing Record Huarmey
# Processing Record Kavieng
# Processing Record Bundaberg
# Processing Record Arraial do Cabo
# Processing Record Provideniya
# Processing Record Upernavik
# Processing Record Hobbs
# Processing Record Saint Anthony
# Processing Record Pemangkat
# Processing Record Belyy Yar
# Processing Record Buala
# Processing Record Ilulissat
# Processing Record Zhigansk
# Processing Record Nowy Dwór Mazowiecki
# Processing Record Beringovskiy
# Processing Record Yulara
# Processing Record Sursk
# Processing Record Ponta do Sol
# Processing Record Iracoubo
# Processing Record Eral
# Processing Record Saskylakh
# Processing Record Sayyan
# Processing Record Pangascasan
# Processing Record Nikolskoye
# Processing Record Saint-François
# Processing Record Avarua
# Processing Record Taiyuan
# Processing Record Quatre Cocos
# Processing Record ‘Ewa Beach
# Processing Record Øksfjord
# Processing Record Oranjemund
# Processing Record Wuwei
# Processing Record Ozieri
# Processing Record Deputatsky
# Processing Record George Town
# Processing Record Hithadhoo
# Processing Record Busselton
# Processing Record Yatou
# Processing Record Pevek
# Processing Record Visnes
# Processing Record Ribeira Grande
# Processing Record Severo-Kuril'sk
# Processing Record San Luis
# Processing Record Pontal do Paraná
# Processing Record Khatanga
# Processing Record Margate
# Processing Record Gigmoto
# Processing Record Saint-Philippe
# Processing Record Varberg
# Processing Record Belmonte
# Processing Record Bereda
# Processing Record Tiksi
# Processing Record Bambous Virieux
# Processing Record Saint Paul Harbor
# Processing Record Road Town
# Processing Record Hong Kong
# Processing Record Fortuna
# Processing Record Broome
# Processing Record Žemaičių Naumiestis
# Processing Record Baharly
# Processing Record San Patricio
# Processing Record Hohhot
# Processing Record Chunoyar
# Processing Record Lodja
# Processing Record Vacaria
# Processing Record Dekar
# Processing Record Rozsypne
# Processing Record Methóni
# Processing Record Lompoc
# Processing Record Tucumcari
# Processing Record Semey
# Processing Record Kismayo
# Processing Record Mahébourg
# Processing Record Winnemucca
# Processing Record Lauria
# Processing Record Sitka
# Processing Record Port Hardy
# Processing Record Cidreira
# Processing Record Kaitong
# Processing Record Olinda
# Processing Record Grindavik
# Processing Record Castro
# Processing Record Altamira
# Processing Record Syracuse
# Processing Record Geraldton
# Processing Record Chekhov
# Processing Record Samfya
# Processing Record Uusikaupunki
# Processing Record Lima
# Processing Record Reconquista
# Processing Record Shemonaīkha
# Processing Record Genhe
# Processing Record Villa Bruzual
# Processing Record Clyde River
# Processing Record Nome
# Processing Record Maniitsoq
# Processing Record Isangel
# Processing Record Naze
# Processing Record Kargopol'
# Processing Record Mandan
# Processing Record Burnie
# Processing Record Bethel
# Processing Record Aklavik
# Processing Record Schladming
# Processing Record Aasiaat
# Processing Record Faro
# Processing Record Kruisfontein
# Processing Record Havøysund
# Processing Record Shumyachi
# Processing Record Jumla
# Processing Record Buhe
# Processing Record Xining
# Processing Record Honiara
# Processing Record Beloha
# Processing Record Cabo San Lucas
# Processing Record Kyabé
# Processing Record Mikhaylovka
# Processing Record Araceli
# Processing Record Moengo
# Processing Record Flin Flon
# Processing Record Vestmannaeyjar
# Processing Record Salalah
# Processing Record Tasiilaq
# Processing Record Port Moresby
# Processing Record Dikson
# Processing Record Minudasht
# Processing Record Bosobolo
# Processing Record Grand-Lahou
# Processing Record Batticaloa
# Processing Record Guerrero Negro
# Processing Record Harper
# Processing Record Acaraú
# Processing Record Shimoda
# Processing Record Takoradze
# Processing Record Hambantota
# Processing Record Dunedin
# Processing Record Arrondissement de Bernay
# Processing Record Mackay
# Processing Record Portland
# Processing Record Airai
# Processing Record Bengkulu
# Processing Record Superior
# Processing Record Gimli
# Processing Record Carnarvon
# Processing Record Urengoy
# Processing Record Bathsheba
# Processing Record Oyem
# Processing Record Biu
# Processing Record Bima
# Processing Record Mezen'
# Processing Record Aykhal
# Processing Record Port Blair
# Processing Record Richards Bay
# Processing Record Mossamedes
# Processing Record Sittwe
# Processing Record Malanje
# Processing Record Laas
# Processing Record La Maddalena
# Processing Record Palmer
# Processing Record Bumba
# Processing Record Haines Junction
# Processing Record Henties Bay
# Processing Record San Policarpo
# Processing Record Lüderitz
# Processing Record Mount Isa
# Processing Record Oktyabr'skoye
# Processing Record Teahupoo
# Processing Record Ponferrada
# Processing Record Los Llanos de Aridane
# Processing Record Vostok
# Processing Record Dudinka
# Processing Record Rāpar
# Processing Record Benguela
# Processing Record Kaeo
# Processing Record Alice Springs
# Processing Record San Cristobal
# Processing Record Hualmay
# Processing Record Chokurdakh
# Processing Record Lagoa
# Processing Record Zapolyarnyy
# Processing Record Wajir
# Processing Record Przasnysz
# Processing Record Port Elizabeth
# Processing Record Wanning
# Processing Record Avanigadda
# Processing Record Christchurch
# Processing Record Krasnosel'kup
# Processing Record Paita
# Processing Record Burhaniye
# Processing Record Qasigiannguit
# Processing Record Arrondissement d'Ajaccio
# Processing Record Neturhāt
# Processing Record Jalu
# Processing Record Qaqortoq
# Processing Record Kamaishi
# Processing Record Kerrobert
# Processing Record Praia da Vitória
# Processing Record Carutapera
# Processing Record Itarema
# Processing Record Cherskiy
# Processing Record Mastic Beach
# Processing Record Charters Towers
# Processing Record Hyères
# Processing Record Gushikawa
# Processing Record Alofi
# Processing Record Ulaangom
# Processing Record Polohy
# Processing Record Scarborough
# Processing Record Johnstown
# Processing Record Lander
# Processing Record Talcahuano
# Processing Record Khovu-Aksy
# Processing Record Chippewa Falls
# Processing Record Nador
# Processing Record Narsaq
# Processing Record Nānākuli
# Processing Record Nouadhibou
# Processing Record Katsuura
# Processing Record Rudno
# Processing Record Isabela
# Processing Record Sørland
# Processing Record Dejen
# Processing Record Mēga
# Processing Record Saint-Pierre
# Processing Record Nakasongola
# Processing Record Hurricane
# Processing Record Seoul
# Processing Record Kaseda-shirakame
# Processing Record Los Andes
# Processing Record Ada
# Processing Record Birmingham
# Processing Record Mathbaria
# Processing Record Sur
# Processing Record Lorengau
# Processing Record West Wendover
# Processing Record Ostrovnoy
# Processing Record Aksay
# Processing Record Leningradskiy
# Processing Record Kashgar
# Processing Record Sangmélima
# Processing Record Waitati
# Processing Record Atambua
# Processing Record Kavaratti
# Processing Record Lékoni
# Processing Record Inzer
# Processing Record Cacequi
# Processing Record Sankheda
# Processing Record Laguna
# Processing Record Presidencia Roque Sáenz Peña
# Processing Record Ketchikan
# Processing Record Rincon
# Processing Record Port Lincoln
# Processing Record Newport
# Processing Record The Valley
# Processing Record Nālūt
# Processing Record Half Moon Bay
# Processing Record Kieta
# Processing Record Kvitok
# Processing Record Pierre
# Processing Record Ambon City
# Processing Record Waingapu
# Processing Record Saint-Leu
# Processing Record Jacareacanga
# Processing Record Constitución
# Processing Record Bollnäs
# Processing Record Snåase
# Processing Record Ntcheu
# Processing Record Pandan
# Processing Record Koulamoutou
# Processing Record Socorro
# Processing Record Qom
# Processing Record Puerto del Rosario
# Processing Record Makakilo City
# Processing Record Dolores
# Processing Record Asahikawa
# Processing Record Vanimo
# Processing Record Nelson Bay
# Processing Record São Miguel do Araguaia
# Processing Record Igarka
# Processing Record Yarmouth
# Processing Record Ewo
# Processing Record Port Washington
# Processing Record Bonwapitse
# Processing Record Tomatlán
# Processing Record Cairns
# Processing Record Lerwick
# Processing Record Eldorado
# Processing Record San José de Río Tinto
# Processing Record Grand Gaube
# Processing Record Cuamba
# Processing Record Tuatapere
# Processing Record Cockburn Town
# Processing Record Pandamatenga
# Processing Record Ishinomaki
# Processing Record Belaya Gora
# Processing Record Cartagena
# Processing Record Caicó
# Processing Record Wangqing
# Processing Record Poya
# Processing Record Kudahuvadhoo
# Processing Record Diffa
# Processing Record Znamenskoye
# Processing Record Nabire
# Processing Record Constantine
# Processing Record Zlobin
# Processing Record Yeppoon
# Processing Record Te Anau
# Processing Record Várzea da Palma
# Processing Record Mandurah
# Processing Record Marzuq
# Processing Record Nhulunbuy
# Processing Record Kailua
# Processing Record Westport
# Processing Record Tucuruí
# Processing Record Hay River
# Processing Record Karratha
# Processing Record Pisco
# Processing Record Druzhba
# Processing Record Gummidipundi
# Processing Record Vanavara
# Processing Record Wajima
# Processing Record Kurumkan
# Processing Record Kenai
# Processing Record Malatya Province
# Processing Record Crixás
# Processing Record La Tuque
# Processing Record Wuda
# Processing Record Mt. Pleasant
# Processing Record Batemans Bay
# Processing Record Nadvoitsy
# Processing Record Talakan
# Processing Record Maceió
# Processing Record Avera
# Processing Record Vila Velha
# Processing Record Baturaja
# Processing Record Forsytheganj
# Processing Record Iranshahr
# Processing Record Mount Gambier
# Processing Record Bac Lieu
# Processing Record Merauke
# Processing Record Orël-Izumrud
# Processing Record Galle
# Processing Record Chui
# Processing Record Ouadda
# Processing Record Kupang
# Processing Record Petauke
# Processing Record Chunskiy
# Processing Record Sola
# Processing Record Mīrābād
# Processing Record Caxito
# Processing Record Marawi
# Processing Record Monticello
# Processing Record Newtownards
# Processing Record Hobyo
# Processing Record Suntar
# Processing Record Provincia di Campobasso
# Processing Record Astoria
# Processing Record Sines Municipality
# Processing Record Bilibino
# Processing Record Mirny
# Processing Record Mehamn
# Processing Record Mariehamn
# Processing Record Ghanzi
# Processing Record Sept-Îles
# Processing Record Kanniyākumāri
# Processing Record Simpang
# Processing Record Terekli-Mekteb
# Processing Record Hammerfest
# Processing Record Labuhan
# Processing Record Carballo
# Processing Record Ust'-Kut
# Processing Record Ventspils
# Processing Record Pangnirtung
# Processing Record Darnah
# Processing Record Mlimba
# Processing Record Codrington
# Processing Record Banda Aceh
# Processing Record Gornopravdinsk
# Processing Record Artyom
# Processing Record Aksarka
# Processing Record Bambanglipuro
# Processing Record Siderno
# Processing Record Kovdor
# Processing Record Maragogi
# Processing Record Srednekolymsk
# Processing Record Shache
# Processing Record Kumul
# Processing Record Amazar
# Processing Record Najrān
# Processing Record Pathein
# Processing Record Sankt Florian
# Processing Record Bāntva
# Processing Record Vila Franca do Campo
# Processing Record Enid
# Processing Record Port Hedland
# Processing Record Guilin
# Processing Record Saquena
# Processing Record Iquitos
# Processing Record Griffith
# Processing Record Levice
# Processing Record Gijang
# Processing Record Mil'kovo
# Processing Record Kununurra
# Processing Record Virginia Beach
# Processing Record Zhigalovo
# Processing Record Poykovskiy
# Processing Record Pendleton
# Processing Record Prainha
# Processing Record Yar-Sale
# Processing Record Gogrial
# Processing Record Myitkyina
# Processing Record Pismo Beach
# Processing Record Telhāra
# Processing Record Hamada
# Processing Record Salta
# Processing Record Baykit
# Processing Record Iskateley
# Processing Record Egvekinot
# Processing Record Khipro
# Processing Record Paragominas
# Processing Record Sistranda
# Processing Record Kozachi Laheri
# Processing Record Tutóia
# Processing Record Mokhsogollokh
# Processing Record Santa Maria
# Processing Record Ancud
# Processing Record Verkhnevilyuysk
# Processing Record Corvallis
# Processing Record Gdynia
# Processing Record Lesozavodsk
# Processing Record Muros
# Processing Record Colares
# Processing Record Cap Malheureux
# Processing Record Elizabeth City
# Processing Record Biak
# Processing Record Erenhot
# Processing Record General Roca
# Processing Record Bubaque
# Processing Record Umluj
# Processing Record Viedma
# Processing Record Trincomalee
# Processing Record Palora
# Processing Record Sulangan
# Processing Record Fort Nelson
# Processing Record Orizona
# Processing Record Norman Wells
# Processing Record Palana
# Processing Record Irbeyskoye
# Processing Record Pahrump
# Processing Record Bonavista
# Processing Record Ankpa
# Processing Record Manono
# Processing Record Pingdu
# Processing Record Dauphin
# Processing Record Khandyga
# Processing Record Riyadh
# Processing Record Rio Grande
# Processing Record Okha
# Processing Record Khani
# Processing Record Kozhva
# Processing Record Manicoré
# Processing Record Poum
# Processing Record Guarapari
# Processing Record Sangar
# Processing Record Diré
# Processing Record Lishu
# Processing Record Vilhena
# Processing Record Ozuluama de Mascareñas
# Processing Record Shalyhyne
# Processing Record Batagay-Alyta
# Processing Record Acajutla
# Processing Record Piúma
# Processing Record Marsh Harbour
# Processing Record Kefamenanu
# Processing Record Keningau
# Processing Record Doha
# Processing Record Teya
# Processing Record Sarangani
# Processing Record Peace River
# Processing Record Porto Walter
# Processing Record Puerto Gaitán
# Processing Record Aginskoye
# Processing Record Río Gallegos
# Processing Record Kohima
# Processing Record Yangi Marg`ilon
# Processing Record Russell
# Processing Record Chu
# Processing Record Coahuayana Viejo
# Processing Record Charter Township of Clinton
# Processing Record Ukiah
# Processing Record Leh
# Processing Record Pirgos

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
all_weather_df = pd.DataFrame(all_citydata)   
all_weather_df.to_csv('CityWeather.csv')
all_weather_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Hermanus -34.4187   19.2345     64.00        68           3        1.01
# 1  Hamilton  39.1834  -84.5333     61.00        44           1       13.80
# 2     Vaini -21.2000 -175.2000     75.20        83          20       10.36
# 3   Yukhnov  54.7444   35.2297     49.23        63          61        5.55
# 4   Ziniaré  12.5822   -1.2983    102.20        25           0        5.75
#
#   Country        Date
# 0      ZA  1619886496
# 1      US  1619886241
# 2      TO  1619886429
# 3      RU  1619886518
# 4      BF  1619886518

# %%
all_weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  581.000000  581.000000  581.000000  581.000000  581.000000  581.000000
# mean    21.472849   20.684647   61.946816   68.185886   54.392427    7.948399
# std     33.726465   89.308671   20.176804   21.966665   38.242703    5.048277
# min    -54.800000 -179.166700   -5.840000    3.000000    0.000000    0.200000
# 25%     -7.900000  -54.400000   46.990000   54.000000   20.000000    4.230000
# 50%     28.017000   23.433300   66.200000   73.000000   64.000000    6.910000
# 75%     50.316700  101.766700   77.490000   86.000000   90.000000   10.560000
# max     78.218600  179.316700  107.400000  100.000000  100.000000   34.520000
#
#                Date
# count  5.810000e+02
# mean   1.619887e+09
# std    8.314157e+01
# min    1.619886e+09
# 25%    1.619887e+09
# 50%    1.619887e+09
# 75%    1.619887e+09
# max    1.619887e+09

# %% [markdown]
# Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#  Get the indices of cities that have humidity over 100%.
all_weather_df['Humidity'] = pd.to_numeric(all_weather_df['Humidity'])
all_weather_df.loc(['Humidity'] > 100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f2677fdb0ad7> in <module>
#       3 #  Get the indices of cities that have humidity over 100%.
#       4 all_weather_df['Humidity'] = pd.to_numeric(all_weather_df['Humidity'])
# ----> 5 all_weather_df.loc(['Humidity'] > 100)
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
all_weather_df = all_weather_df.drop(all_weather_df[all_weather_df.Humidity > 100].index)
all_weather_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Hermanus -34.4187   19.2345     64.00        68           3        1.01
# 1  Hamilton  39.1834  -84.5333     61.00        44           1       13.80
# 2     Vaini -21.2000 -175.2000     75.20        83          20       10.36
# 3   Yukhnov  54.7444   35.2297     49.23        63          61        5.55
# 4   Ziniaré  12.5822   -1.2983    102.20        25           0        5.75
#
#   Country        Date
# 0      ZA  1619886496
# 1      US  1619886241
# 2      TO  1619886429
# 3      RU  1619886518
# 4      BF  1619886518

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
all_weather_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8),
              title="Latitude vs. Temperature Plot")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
all_weather_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8),
              title="Latitude vs. Humidity Plot")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
all_weather_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8),
              title="Latitude vs. Cloudiness Plot")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
all_weather_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8),
              title="Latitude vs. Wind Speed Plot")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.3647131244835288

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 6.813305368486179e-05

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 6.813305368486179e-05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.030721815952682092

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.030721815952682092

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.011257497917361204

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = all_weather_df['Lat']
y_values = all_weather_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.011257497917361204
